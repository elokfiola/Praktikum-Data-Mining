# %%
pip install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.4.2)

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

edges = [
    (1,2), (1,3), (2,3),
    (3,4), (4,5), (5,6),
    (4,6), (1,5), (2,4),
]

G.add_edges_from(edges)

nx.draw(G, with_labels=True, node_color='skyblue', node_size=800, font_size=16)
plt.show()

clustering_coeffs = nx.clustering(G)
print("Clustering Coefficients untuk setiap node :")
for node, coeff in clustering_coeffs.items():
    print(f"Node {node}: {coeff : .2f}")

average_clustering = nx.average_clustering(G)
print(f"\nAverage Clustering Coefficient : {average_clustering : .2f}")
# Out:
# Clustering Coefficients untuk setiap node :
# Node 1:  0.33
# Node 2:  0.67
# Node 3:  0.67
# Node 4:  0.33
# Node 5:  0.33
# Node 6:  1.00
#
# Average Clustering Coefficient :  0.56

# %%
efficiency = nx.global_efficiency(G)
print(f"\nGlobal Efficiency of the graph : {efficiency : .2f}")
# Out:
# Global Efficiency of the graph :  0.80

# %%
degree_centrality = nx.degree_centrality(G)
print("Degree Centrality:")
for node, centrality in degree_centrality.items():
    print(f"Node {node}: {centrality : .2f}")

eccentricity = nx.eccentricity(G)
print("\nEccentricity:")
for node, ecc in eccentricity.items():
    print(f"Node {node}: {ecc}")

closeness_centrality = nx.closeness_centrality(G)
print("\nCloseness Centrality:")
for node, centrality in closeness_centrality.items():
    print(f"Node {node}: {centrality : .2f}")

betweenness_centrality = nx.betweenness_centrality(G)
print("\nBetweenness Centrality:")
for node, centrality in betweenness_centrality.items():
    print(f"Node {node}: {centrality : .2f}")
# Out:
# Degree Centrality:
# Node 1:  0.60
# Node 2:  0.60
# Node 3:  0.60
# Node 4:  0.80
# Node 5:  0.60
# Node 6:  0.40
#
# Eccentricity:
# Node 1: 2
# Node 2: 2
# Node 3: 2
# Node 4: 2
# Node 5: 2
# Node 6: 2
#
# Closeness Centrality:
# Node 1:  0.71
# Node 2:  0.71
# Node 3:  0.71
# Node 4:  0.83
# Node 5:  0.71
# Node 6:  0.62
#
# Betweenness Centrality:
# Node 1:  0.10
# Node 2:  0.03
# Node 3:  0.03
# Node 4:  0.30
# Node 5:  0.13
# Node 6:  0.00

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import pairwise_distances
from matplotlib import pyplot as plt

data = {
    'Panjang Petal' : np.random.normal(loc=3.5, scale=0.5, size=10),
    'Lebar Petal' : np.random.normal(loc=1.0, scale=0.3, size=10),
    'Panjang Sepal' : np.random.normal(loc=5.0, scale=0.5, size=10),
    'Lebar Sepal' : np.random.normal(loc=1.5, scale=0.3, size=10)
}
df = pd.DataFrame(data)

distances = pairwise_distances(df)
treshold = 0.7
G = nx.Graph()

for i in range(len(distances)):
    for j in range(i+1, len(distances)):
        if distances[i][j] < treshold:
            G.add_edge(i, j)

# %%
if G.number_of_nodes() > 0:
    clustering_coeffs = nx.clustering(G)
    average_clustering = nx.average_clustering(G)
else :
  clustering_coeffs = {}
  average_clustering = 0

if G.number_of_nodes() > 0:
    efficiency = nx.global_efficiency(G)
else :
  efficiency = 0

degree_centrality = nx.degree_centrality(G)
eccentricity = nx.eccentricity(G)
closeness_centrality = nx.closeness_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G)

print("clustering coefficient : ")
for node, coeff in clustering_coeffs.items():
    print(f"Node {node}: {coeff : .2f}")
print(f"\nAverage Clustering Coefficient : {average_clustering : .2f}")

print(f"\nGlobal Efficiency: {efficiency : .2f}")

print("\nDegree Centrality:")
for node, centrality in degree_centrality.items():
    print(f"Node {node}: {centrality : .2f}")

print("\nEccentricity:")
for node, ecc in eccentricity.items():
    print(f"Node {node}: {ecc}")

print("\nCloseness Centrality:")
for node, centrality in closeness_centrality.items():
    print(f"Node {node}: {centrality : .2f}")

print("\nBetweenness Centrality:")
for node, centrality in betweenness_centrality.items():
    print(f"Node {node}: {centrality : .2f}")
# Out:
# clustering coefficient :
# Node 6:  1.00
# Node 7:  1.00
# Node 8:  1.00
# Node 9:  1.00
#
# Average Clustering Coefficient :  1.00
#
# Global Efficiency:  1.00
#
# Degree Centrality:
# Node 6:  1.00
# Node 7:  1.00
# Node 8:  1.00
# Node 9:  1.00
#
# Eccentricity:
# Node 6: 1
# Node 7: 1
# Node 8: 1
# Node 9: 1
#
# Closeness Centrality:
# Node 6:  1.00
# Node 7:  1.00
# Node 8:  1.00
# Node 9:  1.00
#
# Betweenness Centrality:
# Node 6:  0.00
# Node 7:  0.00
# Node 8:  0.00
# Node 9:  0.00

# %%
plt.figure(figsize=(10, 8))
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, node_size=300)
nx.draw_networkx_edges(G, pos)
nx.draw_networkx_labels(G, pos, font_size=12)
plt.title("Graph representation of the dataset")
plt.axis('off')
plt.show()

# %% [markdown]
# ##Tugas Individu Praktikum 7
